# %% [markdown]
# # Document Classification with Naive Bayes - Lab
# https://github.com/learn-co-students/dsc-document-classification-with-naive-bayes-lab-online-ds-pt-100719/tree/solution
#
# ## Introduction
#
# In this lesson, you'll practice implementing the Naive Bayes algorithm on your own.
#
# ## Objectives
#
# In this lab you will:
#
# * Implement document classification using Naive Bayes

# %% [markdown]
# ## Import the dataset
#
# To start, import the dataset stored in the text file `'SMSSpamCollection'`.

# %%
# Your code here
from fsds_100719.imports import *

df = pd.read_csv('SMSSpamCollection',sep='\t',names=['label','text'])
df.head()
# Out:
# fsds_1007219  v0.7.17 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row1_col1" class="data row1 col1" >fsds_100719</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_1e3e5ae6_75c4_11ea_b8a8_acde48001122row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Account for class imbalance
#
# To help your algorithm perform more accurately, subset the dataset so that the two classes are of equal size. To do this, keep all of the instances of the minority class (spam) and subset examples of the majority class (ham) to an equal number of examples.

# %%
df['label'].value_counts(normalize=False).idxmin()
# Out:
# 'spam'

# %%
# Your code here
df['label'].value_counts(normalize=True)
# Out:
# ham     0.865937
# spam    0.134063
# Name: label, dtype: float64

# %%
def undersample_df(df, col='label',random_state=42):
    """Undersample dataframe to match minority class count in col"""
    val_counts =  df[col].value_counts()
    minority_count = val_counts.min()

    df2  = pd.DataFrame(columns=df.columns)
    for grp,idx in df.groupby(col).groups.items():

        df_temp = df.loc[idx].sample(n=minority_count,random_state=random_state)
        df2 = pd.concat([df2,df_temp],axis=0)
    
    return df2

# %%
df2 = undersample_df(df)
df2.head()
# Out:
#      label                                               text
# 3714   ham  If i not meeting ü all rite then i'll go home ...
# 1311   ham  I.ll always be there, even if its just in spir...
# 548    ham                   Sorry that took so long, omw now
# 1324   ham  I thk 50 shd be ok he said plus minus 10.. Did...
# 3184   ham  Dunno i juz askin cos i got a card got 20% off...

# %%
df2['label'].value_counts()
# Out:
# spam    747
# ham     747
# Name: label, dtype: int64

# %%
p_classes=dict(df2['label'].value_counts(normalize=True))
p_classes
# Out:
# {'spam': 0.5, 'ham': 0.5}

# %% [markdown]
# ## Train-test split
#
# Now implement a train-test split on the dataset:

# %%
# Your code here
from sklearn.model_selection import train_test_split
X = df2['text'].copy()
y = df2['label'].copy()
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=17)
train_df = pd.concat([X_train,y_train],axis=1)
test_df = pd.concat([X_test,y_test],axis=1)

# %% [markdown]
# ## Create the word frequency dictionary for each class
#
# Create a word frequency dictionary for each class:

# %%
## my way
from collections import Counter

class_word_freq = {}
for class_ in  train_df['label'].unique():
    text = train_df[train_df['label']==class_]['text']
    text = ' '.join(text)

    class_word_freq[class_] = Counter(text.split(' '))
class_word_freq.keys()
# Out:
# dict_keys(['spam', 'ham'])

# %%
## Solution way
class_word_freq = {} 
classes = train_df['label'].unique()
for class_ in classes:
    temp_df = train_df[train_df['label'] == class_]
    bag = {}
    for row in temp_df.index:
        doc = temp_df['text'][row]
        for word in doc.split():
            bag[word] = bag.get(word, 0) + 1
    class_word_freq[class_] = bag
class_word_freq.keys()
# Out:
# dict_keys(['spam', 'ham'])

# %% [markdown]
# ## Count the total corpus words
# Calculate V, the total number of words in the corpus:

# %%
## My way
def join_freq_dicts(*ds):
    """Combines any number of frequency word dicts"""
    D = {}
    for d in ds:
        for k,v in d.items():
            cur_v = D.get(k,0)
            D[k] = cur_v+v
    return D

vocab = join_freq_dicts(*list(class_word_freq.values()))
V = len(vocab)
V
# Out:
# 5958

# %%
## Solution way
vocabulary = set()
for text in train_df['text']:
    for word in text.split():
        vocabulary.add(word)
V = len(vocabulary)
V
# Out:
# 5958

# %% [markdown]
# ## Create a bag of words function
#
# Before implementing the entire Naive Bayes algorithm, create a helper function `bag_it()` to create a bag of words representation from a document's text.

# %%
# May way
def bag_it(doc):
    return Counter(doc.split())
bag_it(X_train.iloc[0])
# Out:
# Counter({'25p': 1,
#          '4': 1,
#          'alfie': 1,
#          "Moon's": 1,
#          'Children': 1,
#          'in': 1,
#          'need': 1,
#          'song': 1,
#          'on': 1,
#          'ur': 2,
#          'mob.': 1,
#          'Tell': 1,
#          'm8s.': 1,
#          'Txt': 1,
#          'Tone': 1,
#          'charity': 2,
#          'to': 1,
#          '8007': 1,
#          'for': 2,
#          'Nokias': 1,
#          'or': 1,
#          'Poly': 1,
#          'polys:': 1,
#          'zed': 1,
#          '08701417012': 1,
#          'profit': 1,
#          '2': 1,
#          'charity.': 1})

# %%
## Solution way
def bag_it(doc):
    bag = {}
    for word in doc.split():
        bag[word] = bag.get(word, 0) + 1
    return bag

# %%
bag_it(X_train.iloc[0])
# Out:
# {'25p': 1,
#  '4': 1,
#  'alfie': 1,
#  "Moon's": 1,
#  'Children': 1,
#  'in': 1,
#  'need': 1,
#  'song': 1,
#  'on': 1,
#  'ur': 2,
#  'mob.': 1,
#  'Tell': 1,
#  'm8s.': 1,
#  'Txt': 1,
#  'Tone': 1,
#  'charity': 2,
#  'to': 1,
#  '8007': 1,
#  'for': 2,
#  'Nokias': 1,
#  'or': 1,
#  'Poly': 1,
#  'polys:': 1,
#  'zed': 1,
#  '08701417012': 1,
#  'profit': 1,
#  '2': 1,
#  'charity.': 1}

# %% [markdown]
# ## Implementing Naive Bayes
#
# Now, implement a master function to build a naive Bayes classifier. Be sure to use the logarithmic probabilities to avoid underflow.

# %%
# Solution way
def classify_doc(doc, class_word_freq, p_classes, V, return_posteriors=False):
    bag = bag_it(doc)
    classes = []
    posteriors = []
    
    for class_ in class_word_freq.keys():
        p = np.log(p_classes[class_])
        
        for word in bag.keys():
            num = bag[word]+1
            denom = class_word_freq[class_].get(word, 0) + V
            p += np.log(num/denom)
        classes.append(class_)
        posteriors.append(p)
    if return_posteriors:
        print(posteriors)
    return classes[np.argmax(posteriors)]

# %% [markdown]
# ## Test your classifier
#
# Finally, test your classifier and measure its accuracy. Don't be perturbed if your results are sub-par; industry use cases would require substantial additional preprocessing before implementing the algorithm in practice.

# %%
class_word_freq
# Out:
# {'spam': {'25p': 6,
#   '4': 71,
#   'alfie': 1,
#   "Moon's": 2,
#   'Children': 2,
#   'in': 46,
#   'need': 3,
#   'song': 2,
#   'on': 109,
#   'ur': 75,
#   'mob.': 2,
#   'Tell': 2,
#   'm8s.': 2,
#   'Txt': 45,
#   'Tone': 8,
#   'charity': 3,
#   'to': 461,
#   '8007': 15,
#   'for': 138,
#   'Nokias': 1,
#   'or': 149,
#   'Poly': 1,
#   'polys:': 1,
#   'zed': 3,
#   '08701417012': 2,
#   'profit': 2,
#   '2': 116,
#   'charity.': 1,
#   'New': 12,
#   'TEXTBUDDY': 2,
#   'Chat': 6,
#   'horny': 4,
#   'guys': 3,
#   'area': 3,
#   'just': 41,
#   'Free': 23,
#   'receive': 23,
#   'Search': 2,
#   'postcode': 3,
#   'at': 21,
#   'gaytextbuddy.com.': 2,
#   'TXT': 3,
#   'ONE': 3,
#   'name': 5,
#   '89693': 1,
#   'all': 20,
#   'the': 126,
#   'lastest': 1,
#   'from': 87,
#   'Stereophonics,': 1,
#   'Marley,': 1,
#   'Dizzee': 1,
#   'Racal,': 1,
#   'Libertines': 1,
#   'and': 90,
#   'The': 16,
#   'Strokes!': 1,
#   'Win': 9,
#   'Nookii': 1,
#   'games': 3,
#   'with': 72,
#   'Flirt!!': 1,
#   'Click': 2,
#   'TheMob': 1,
#   'WAP': 6,
#   'Bookmark': 1,
#   'text': 53,
#   '82468': 2,
#   'Marvel': 1,
#   'Mobile': 21,
#   'Play': 5,
#   'official': 5,
#   'Ultimate': 1,
#   'Spider-man': 1,
#   'game': 3,
#   '(£4.50)': 1,
#   'mobile': 69,
#   'right': 1,
#   'now.': 13,
#   'Text': 34,
#   'SPIDER': 1,
#   '83338': 1,
#   '&': 72,
#   'we': 9,
#   'll': 1,
#   'send': 36,
#   'u': 36,
#   'a': 259,
#   'FREE': 66,
#   '8Ball': 1,
#   'wallpaper': 2,
#   'Moby': 2,
#   'Pub': 2,
#   'Quiz.Win': 2,
#   '£100': 16,
#   'High': 2,
#   'Street': 2,
#   'prize': 38,
#   'if': 14,
#   'know': 18,
#   'who': 32,
#   'new': 29,
#   'Duchess': 2,
#   'of': 64,
#   'Cornwall': 2,
#   'will': 32,
#   'be?': 2,
#   'her': 7,
#   'first': 2,
#   '82277.unsub': 2,
#   'STOP': 38,
#   '£1.50': 16,
#   '008704050406': 2,
#   'SP': 3,
#   'Wan2': 2,
#   'win': 18,
#   'Meet+Greet': 2,
#   'Westlife': 2,
#   'U': 50,
#   'm8?': 2,
#   'They': 2,
#   'are': 59,
#   'currently': 7,
#   'what': 10,
#   'tour?': 2,
#   '1)Unbreakable,': 2,
#   '2)Untamed,': 2,
#   '3)Unkempt.': 2,
#   '1,2': 2,
#   '3': 16,
#   '83049.': 2,
#   'Cost': 11,
#   '50p': 3,
#   '+std': 2,
#   'UR': 16,
#   'awarded': 27,
#   'City': 2,
#   'Break': 3,
#   'could': 4,
#   'WIN': 13,
#   '£200': 5,
#   'Summer': 2,
#   'Shopping': 2,
#   'spree': 2,
#   'every': 24,
#   'WK.': 2,
#   'STORE': 2,
#   '88039.SkilGme.TsCs087147403231Winawk!Age16+£1.50perWKsub': 1,
#   '44': 1,
#   '7732584351,': 1,
#   'Do': 12,
#   'you': 136,
#   'want': 13,
#   'Nokia': 37,
#   '3510i': 4,
#   'colour': 13,
#   'phone': 21,
#   'DeliveredTomorrow?': 2,
#   'With': 5,
#   '300': 2,
#   'free': 44,
#   'minutes': 4,
#   'any': 20,
#   '+': 14,
#   '100': 11,
#   'texts': 13,
#   'Camcorder': 3,
#   'reply': 43,
#   'call': 150,
#   '08000930705.': 1,
#   'Call': 106,
#   'FREEPHONE': 6,
#   '0800': 9,
#   '542': 3,
#   '0578': 2,
#   'now!': 38,
#   'have': 93,
#   'Secret': 2,
#   'Admirer': 2,
#   'is': 108,
#   'looking': 7,
#   'make': 9,
#   'contact': 43,
#   'U-find': 6,
#   'out': 34,
#   'they': 11,
#   'R*reveal': 6,
#   'thinks': 8,
#   'so': 17,
#   'special-call': 6,
#   '09065171142-stopsms-08718727870150ppm': 1,
#   'FreeMsg': 4,
#   'Hi': 9,
#   'baby': 1,
#   'wow': 1,
#   'got': 4,
#   'cam': 2,
#   'moby.': 1,
#   'Wanna': 6,
#   'C': 9,
#   'hot': 5,
#   'pic?': 1,
#   'Fancy': 5,
#   'chat?Im': 1,
#   'w8in': 1,
#   '4uTxt': 1,
#   '/': 1,
#   'rply': 3,
#   'CHAT': 10,
#   '82242': 3,
#   'Hlp': 2,
#   '08712317606': 2,
#   'Msg150p': 2,
#   '2rcv': 2,
#   'Will': 1,
#   'meet': 3,
#   'dream': 1,
#   'partner': 3,
#   'soon?': 1,
#   'Is': 1,
#   'career': 1,
#   'off': 1,
#   'flyng': 1,
#   'start?': 1,
#   'find': 14,
#   'free,': 2,
#   'txt': 53,
#   'HORO': 2,
#   'followed': 3,
#   'by': 26,
#   'star': 1,
#   'sign,': 1,
#   'e.': 2,
#   'g.': 2,
#   'ARIES': 1,
#   'can': 19,
#   'Music': 3,
#   'Gift': 4,
#   'Vouchers': 3,
#   'week': 24,
#   'starting': 3,
#   'NOW': 18,
#   'word': 10,
#   'DRAW': 3,
#   '87066': 8,
#   'TsCs': 3,
#   'www.Idew.com': 2,
#   'SkillGame,': 2,
#   '1Winaweek,': 2,
#   'age16.': 2,
#   '150ppermessSubscription': 2,
#   'GOING': 3,
#   'BAHAMAS!': 2,
#   'CallFREEFONE': 2,
#   '08081560665': 2,
#   'speak': 4,
#   'live': 13,
#   'operator': 10,
#   'claim': 59,
#   'either': 8,
#   'Bahamas': 2,
#   'cruise': 2,
#   'of£2000': 2,
#   'CASH': 8,
#   '18+only.': 2,
#   'To': 63,
#   'opt': 9,
#   'X': 5,
#   '07786200117': 2,
#   'Urgent!': 7,
#   'Please': 26,
#   '09061213237': 2,
#   'landline.': 11,
#   '£5000': 14,
#   'cash': 31,
#   '4*': 16,
#   'holiday': 8,
#   'await': 14,
#   'collection.': 13,
#   'T': 8,
#   '&Cs': 1,
#   'SAE': 11,
#   'PO': 26,
#   'Box': 18,
#   '177': 1,
#   'M227XY.': 2,
#   '16+': 17,
#   'Join': 5,
#   "UK's": 5,
#   'horniest': 1,
#   'Dogging': 9,
#   'service': 36,
#   'sex': 3,
#   '2nite!.': 1,
#   'Just': 23,
#   'sign': 1,
#   'up': 13,
#   'follow': 1,
#   'instructions.': 1,
#   'ENTRY': 1,
#   '69888': 1,
#   'Nyt.EC2A.3LP.msg@150p': 1,
#   "Don't": 2,
#   'b': 2,
#   'floppy...': 1,
#   'snappy': 1,
#   'happy!': 1,
#   'Only': 8,
#   'gay': 4,
#   'chat': 11,
#   'photo': 3,
#   'upload': 2,
#   '08718730666': 2,
#   '(10p/min).': 2,
#   'stop': 32,
#   'our': 57,
#   '08712460324': 7,
#   'Spook': 1,
#   'your': 147,
#   'mob': 12,
#   'Halloween': 2,
#   'collection': 7,
#   'logo': 2,
#   'pic': 2,
#   'message': 16,
#   'plus': 4,
#   'eerie': 2,
#   'tone,': 4,
#   'CARD': 2,
#   'SPOOK': 2,
#   '08701417012150p': 1,
#   'per': 32,
#   'logo/pic': 1,
#   '09066612661': 3,
#   'landline,': 2,
#   'complimentary': 9,
#   'Lux': 1,
#   'Costa': 5,
#   'Del': 6,
#   'Sol': 5,
#   '£1000': 22,
#   'ppm': 2,
#   '150': 5,
#   'T&Cs': 16,
#   'James': 1,
#   '28,': 1,
#   'EH74RR': 1,
#   'secret': 6,
#   'admirer.': 2,
#   'REVEAL': 4,
#   'R': 7,
#   'So': 2,
#   'special.': 2,
#   '09065174042.': 2,
#   'Reply': 32,
#   'STOP.': 8,
#   '1.50': 3,
#   'msg': 12,
#   'recd.': 2,
#   'Cust': 2,
#   'care': 4,
#   '07821230901': 2,
#   'ou': 1,
#   'guaranteed': 19,
#   'latest': 20,
#   'Phone,': 3,
#   '40GB': 3,
#   'iPod': 3,
#   'MP3': 4,
#   'player': 9,
#   '£500': 11,
#   'prize!': 10,
#   'word:': 5,
#   'COLLECT': 3,
#   'No:': 11,
#   '83355!': 2,
#   'IBHltd': 2,
#   'LdnW15H': 2,
#   '150p/Mtmsgrcvd18': 1,
#   'SMS.': 3,
#   'ac': 3,
#   'JSco:': 1,
#   'Energy': 1,
#   'high,': 1,
#   'but': 6,
#   'may': 4,
#   'not': 11,
#   'where': 1,
#   '2channel': 1,
#   'it.': 1,
#   '2day': 2,
#   'leadership': 1,
#   'skills': 1,
#   'r': 10,
#   'strong.': 1,
#   'Psychic?': 1,
#   'ANS': 1,
#   'w/question.': 1,
#   'End?': 1,
#   'END': 1,
#   'JSCO': 1,
#   'laugh?': 1,
#   'Try': 1,
#   'CHIT-CHAT': 1,
#   'Logon': 1,
#   'txting': 8,
#   'it': 16,
#   '8883': 1,
#   'CM': 1,
#   '4217': 1,
#   'London': 4,
#   'W1A': 1,
#   '6ZF': 1,
#   '118p/msg': 1,
#   'rcvd': 2,
#   'For': 16,
#   'chance': 11,
#   'Bluetooth': 8,
#   'Headset': 1,
#   'then': 5,
#   'simply': 1,
#   'back': 11,
#   '"ADP"': 1,
#   'Colour': 2,
#   'Phone': 4,
#   'Delivered': 2,
#   'Tomorrow?': 2,
#   '200': 3,
#   'camcorder': 6,
#   '8000930705': 1,
#   'Hello': 2,
#   'darling': 2,
#   'how': 3,
#   'today?': 1,
#   'I': 19,
#   'would': 1,
#   'love': 5,
#   'chat,': 1,
#   'why': 5,
#   'dont': 3,
#   'tell': 12,
#   'me': 16,
#   'look': 2,
#   'like': 11,
#   'sexy?': 1,
#   'CALL': 18,
#   '08712402972': 1,
#   'immediately': 4,
#   'as': 19,
#   'there': 8,
#   'an': 17,
#   'urgent': 4,
#   'waiting': 13,
#   'Got': 2,
#   'takes': 3,
#   'take': 9,
#   'part': 6,
#   'WRC': 2,
#   'Rally': 2,
#   'Oz?': 2,
#   'Lucozade': 2,
#   'Energy!': 2,
#   'RALLY': 2,
#   'LE': 2,
#   '61200': 2,
#   '(25p),': 2,
#   'see': 7,
#   'packs': 2,
#   'lucozade.co.uk/wrc': 2,
#   'itcould': 2,
#   'be': 39,
#   'u!': 5,
#   '88800': 1,
#   '89034': 1,
#   'premium': 2,
#   'services': 9,
#   '08718711108': 1,
#   'Orange': 16,
#   'brings': 1,
#   'ringtones': 2,
#   'time': 11,
#   'Chart': 1,
#   'Heroes,': 1,
#   'hit': 2,
#   'each': 5,
#   'week!': 11,
#   'Go': 3,
#   'Ringtones': 1,
#   'Pics': 1,
#   'wap.': 2,
#   'receiving': 2,
#   'these': 2,
#   'tips': 1,
#   'Sorry': 1,
#   'missed': 1,
#   "let's": 2,
#   'talk': 4,
#   'when': 6,
#   'time.': 3,
#   "I'm": 6,
#   '07090201529': 1,
#   'shag?': 1,
#   'do.Interested?': 1,
#   'sextextuk.com': 1,
#   'XXUK': 1,
#   'SUZY': 1,
#   '69876.': 1,
#   'Txts': 1,
#   'cost': 7,
#   'msg.': 3,
#   'TnCs': 4,
#   'website.': 1,
#   'admirer': 4,
#   '09058094599': 2,
#   'URGENT!': 25,
#   'Your': 56,
#   'No.': 6,
#   'was': 7,
#   '£2000': 17,
#   'Bonus': 13,
#   'Caller': 8,
#   'Prize': 8,
#   '5/9/03': 1,
#   'This': 29,
#   'final': 9,
#   'try': 2,
#   'U!': 2,
#   'Landline': 4,
#   '09064019788': 1,
#   'BOX42WR29C,': 1,
#   '150PPM': 2,
#   "You've": 2,
#   'won': 30,
#   'tkts': 4,
#   'EURO2004': 2,
#   'CUP': 2,
#   'FINAL': 2,
#   '£800': 8,
#   'CASH,': 2,
#   'collect': 15,
#   '09058099801': 2,
#   'b4190604,': 2,
#   'POBOX': 4,
#   '7876150ppm': 2,
#   '09061749602': 1,
#   'Landline.': 2,
#   'Tenerife': 4,
#   'Holiday': 15,
#   '£10,000': 5,
#   'BOX': 7,
#   '528': 1,
#   'HP20': 1,
#   '1YF': 1,
#   '150ppm': 19,
#   '18+': 12,
#   'ASKED': 1,
#   '3MOBILE': 1,
#   'IF': 1,
#   '0870': 4,
#   'CHATLINES': 1,
#   'INCLU': 1,
#   'IN': 3,
#   'MINS.': 1,
#   'INDIA': 1,
#   'CUST': 1,
#   'SERVs': 1,
#   'SED': 1,
#   'YES.': 2,
#   'L8ER': 1,
#   'GOT': 1,
#   'MEGA': 1,
#   'BILL.': 1,
#   'DONT': 1,
#   'GIV': 1,
#   'A': 14,
#   'SHIT.': 1,
#   'BAILIFF': 1,
#   'DUE': 1,
#   'DAYS.': 1,
#   'O': 1,
#   '£250': 8,
#   'WANT': 1,
#   'Twinks,': 1,
#   'bears,': 1,
#   'scallies,': 1,
#   'skins': 1,
#   'jocks': 1,
#   'calling': 4,
#   'miss': 5,
#   "weekend's": 2,
#   'fun.': 1,
#   '08712466669': 1,
#   '10p/min.': 2,
#   '08712460324(nat': 1,
#   'rate)': 5,
#   'You': 53,
#   'WON': 14,
#   'prize.': 10,
#   'yr': 9,
#   'customer': 26,
#   'representative': 9,
#   '08714712412': 1,
#   'between': 8,
#   '10am-7pm': 3,
#   '10p': 7,
#   'Get': 29,
#   'ENGLAND': 2,
#   'poly': 6,
#   'ringtone': 15,
#   'flag': 4,
#   'yer': 4,
#   'tonights': 2,
#   'game!': 2,
#   'TONE': 9,
#   'FLAG': 4,
#   '84199.': 2,
#   'Optout': 2,
#   'ENG': 4,
#   'Box39822': 4,
#   'W111WX': 4,
#   'okmail:': 1,
#   'Dear': 12,
#   'Dave': 1,
#   'this': 40,
#   'notice': 2,
#   '#5000': 1,
#   'award!': 3,
#   '09061743806': 1,
#   'TCs': 1,
#   'Box326': 1,
#   'CW25WX': 1,
#   'December': 5,
#   'only!': 6,
#   'Had': 13,
#   '11mths+?': 5,
#   'entitled': 8,
#   'update': 6,
#   'camera': 14,
#   'Free!': 6,
#   'Update': 11,
#   'Co': 5,
#   '08002986906': 4,
#   'Jamster!': 1,
#   'get': 28,
#   'HEART': 1,
#   '88888': 1,
#   'T&C': 8,
#   'apply.': 11,
#   '16': 20,
#   'only.': 5,
#   'Need': 3,
#   'Help?': 2,
#   '08701213186.': 1,
#   'We': 24,
#   'trying': 11,
#   'U.': 10,
#   'Todays': 14,
#   'draw': 22,
#   'shows': 25,
#   'that': 19,
#   'GUARANTEED.': 14,
#   '09050003091': 1,
#   'land': 14,
#   'line.': 13,
#   'Claim': 21,
#   'C52.': 1,
#   'Valid12hrs': 3,
#   'only': 35,
#   'number': 23,
#   'has': 24,
#   'been': 33,
#   '<UKP>2000': 1,
#   '09061790125': 1,
#   '3030.': 5,
#   'Valid': 14,
#   '12hrs': 11,
#   'Alfie': 1,
#   'CHARITY': 2,
#   'nokias': 1,
#   'POLY': 2,
#   'polys': 4,
#   ':zed': 1,
#   'FreeMsg:': 3,
#   'flirt?': 1,
#   'DATE': 3,
#   'now': 44,
#   'join': 5,
#   'UKs': 1,
#   'fastest': 1,
#   'growing': 1,
#   'dating': 12,
#   'service.': 3,
#   'Msgs': 2,
#   'optout': 1,
#   '83021.': 1,
#   'specially': 5,
#   'selected': 19,
#   '2000': 1,
#   'pound': 1,
#   '08712402050': 2,
#   'BEFORE': 2,
#   'lines': 2,
#   'close.': 2,
#   '10ppm.': 2,
#   '16+.': 3,
#   'AG': 2,
#   'Promo': 2,
#   'Congrats!': 7,
#   '3G': 3,
#   'Videophones': 3,
#   'yours.': 6,
#   '09063458130': 2,
#   'videochat': 3,
#   'wid': 3,
#   'mates,': 3,
#   'play': 5,
#   'java': 3,
#   'games,': 4,
#   'Dload': 3,
#   'polyPH': 1,
#   'music,': 3,
#   'noline': 3,
#   'rentl.': 3,
#   'Text82228>>': 1,
#   'more': 10,
#   'ringtones,': 1,
#   'logos': 1,
#   'www.txt82228.com.': 1,
#   'Questions:': 1,
#   'info@txt82228.co.uk': 1,
#   'NOKIA': 14,
#   'Or': 3,
#   'Motorola': 5,
#   'upto': 2,
#   '12mths': 1,
#   '1/2price': 1,
#   'linerental,': 1,
#   '500': 16,
#   'x-net': 1,
#   'mins&100txt/mth': 1,
#   "B'tooth*.": 1,
#   'Mobileupd8': 1,
#   '08001950382': 2,
#   '2optout/D3WV': 1,
#   'YOU': 7,
#   'ARE': 2,
#   'CHOSEN': 2,
#   'TO': 4,
#   'RECEIVE': 2,
#   '£350': 9,
#   'AWARD!': 2,
#   'Pls': 3,
#   '09066364311': 2,
#   'award': 7,
#   'which': 8,
#   'valued': 10,
#   'customer.': 4,
#   'Panasonic': 1,
#   'BluetoothHdset': 1,
#   'FREE.': 6,
#   'DoubleMins': 1,
#   'DoubleTxt': 1,
#   'contract.': 1,
#   'MobileUpd8': 14,
#   '08000839402': 14,
#   '2optout': 4,
#   'BANNEDUK': 1,
#   '89555': 2,
#   'see!': 1,
#   '150p': 15,
#   'textoperator': 2,
#   'g696ga': 2,
#   'XXX': 4,
#   'Fantasy': 1,
#   'Football': 1,
#   'TV.': 1,
#   'Sky': 2,
#   'Gamestar': 1,
#   'Active': 1,
#   '£250k': 1,
#   'Dream': 1,
#   'Team.': 1,
#   'Scoring': 1,
#   'starts': 1,
#   'Saturday,': 1,
#   'register': 1,
#   'now!SKY': 1,
#   'OPT': 1,
#   'OUT': 4,
#   '88088': 1,
#   'Bored': 2,
#   'housewives!': 2,
#   'n': 7,
#   'date': 3,
#   '0871750.77.11!': 2,
#   'BT-national': 2,
#   'rate': 9,
#   '10p/min': 3,
#   'landlines!': 2,
#   'someone': 6,
#   'fancies': 3,
#   'you.': 6,
#   '09058097218': 1,
#   'who.': 1,
#   'POBox': 9,
#   '6,': 2,
#   'LS15HB': 2,
#   '-PLS': 1,
#   'bootydelious': 1,
#   '(32/F)': 1,
#   'inviting': 6,
#   'friend.': 6,
#   'YES-434': 1,
#   'NO-434': 1,
#   'See': 10,
#   'her:': 5,
#   'www.SMS.ac/u/bootydelious': 1,
#   'STOP?': 6,
#   'Send': 16,
#   'FRND': 6,
#   '62468': 7,
#   '08702490080': 1,
#   '-': 38,
#   'tells': 1,
#   '09066358152': 1,
#   'enter': 5,
#   'personal': 1,
#   'details': 5,
#   '@': 4,
#   'prompts.': 1,
#   'Careful!': 1,
#   'Voucher': 5,
#   'Holder': 1,
#   '1st': 20,
#   'class': 2,
#   'airport': 1,
#   'lounge': 1,
#   'passes': 1,
#   'using': 1,
#   'voucher': 5,
#   '08704439680.': 1,
#   'When': 1,
#   'booking': 1,
#   'quote': 1,
#   'x': 3,
#   '+123': 2,
#   'Congratulations': 7,
#   "week's": 4,
#   'competition': 2,
#   '£1450': 3,
#   '09050002311': 2,
#   'b4280703.': 2,
#   'T&Cs/stop': 3,
#   'SMS': 9,
#   '08718727868.': 2,
#   'Over': 2,
#   '18': 16,
#   'shopping': 1,
#   'spree,': 1,
#   '08717895698': 1,
#   'Have': 2,
#   'won!': 1,
#   'MobStoreQuiz10ppm': 1,
#   '"3000': 1,
#   'RINGTONE': 3,
#   'NOW!': 12,
#   'TONE.': 1,
#   'Gr8': 4,
#   'TOP': 1,
#   '20': 3,
#   'tones': 11,
#   'wk': 5,
#   '08452810071': 1,
#   'Video': 9,
#   'handset?': 3,
#   '750': 14,
#   'network': 19,
#   'mins?': 5,
#   'UNLIMITED': 5,
#   'TEXT?': 2,
#   'Camcorder?': 3,
#   '08000930705': 13,
#   'del': 1,
#   'Sat': 2,
#   'AM': 1,
#   '*': 1,
#   'FREE*': 1,
#   'POLYPHONIC': 3,
#   'SUPER': 1,
#   '87131': 3,
#   'SN': 1,
#   'PoBox202': 1,
#   'NR31': 1,
#   '7ZS': 1,
#   'subscription': 3,
#   '450pw': 1,
#   'Final': 2,
#   'Chance!': 3,
#   '£150': 6,
#   'worth': 9,
#   'discount': 7,
#   'vouchers': 10,
#   'today!': 6,
#   'YES': 9,
#   '85023': 5,
#   'SavaMob,': 5,
#   'member': 3,
#   'offers': 8,
#   'mobile!': 7,
#   'Cs': 6,
#   'SavaMob': 5,
#   'POBOX84,': 3,
#   'M263UZ.': 3,
#   '£3.00': 5,
#   'Subs': 1,
#   'cmon': 1,
#   'babe,': 1,
#   'horny,': 1,
#   '*turn*': 1,
#   'on!': 2,
#   'fantasy': 1,
#   'babe': 4,
#   '-)': 1,
#   'Im': 4,
#   'hot,': 1,
#   'sticky': 1,
#   'All': 1,
#   'replies': 1,
#   '£1.50.': 1,
#   'cancel': 4,
#   '1': 21,
#   'year': 4,
#   'special': 4,
#   'cinema': 3,
#   'pass': 3,
#   '09061209465': 3,
#   'Suprman': 3,
#   'V,': 3,
#   'Matrix3,': 3,
#   'StarWars3,': 3,
#   'etc': 3,
#   'FREE!': 13,
#   'bx420-ip4-5we.': 3,
#   '150pm.': 3,
#   'Dont': 4,
#   'out!': 4,
#   'Show': 1,
#   'colours!': 1,
#   'Euro': 1,
#   '2004': 4,
#   '2-4-1': 1,
#   'Offer!': 4,
#   'England': 3,
#   'Flag': 1,
#   '3Lions': 1,
#   'tone': 16,
#   'phone!': 2,
#   'following': 4,
#   'info!': 1,
#   'IMPORTANT': 3,
#   'INFORMATION': 2,
#   'ORANGE': 1,
#   'USER': 1,
#   '0796XXXXXX.': 1,
#   'TODAY': 2,
#   'IS': 8,
#   'LUCKY': 2,
#   'DAY!2': 1,
#   'FIND': 2,
#   'WHY': 2,
#   'LOG': 2,
#   'ONTO': 2,
#   'http://www.urawinner.com': 5,
#   "THERE'S": 3,
#   'FANTASTIC': 4,
#   'PRIZEAWAITING': 1,
#   'YOU!': 10,
#   'garden': 2,
#   'ready': 4,
#   'summer': 4,
#   'selection': 5,
#   'bulbs': 2,
#   'seeds': 2,
#   '£33:50': 2,
#   'Scotsman': 2,
#   'Saturday.': 2,
#   'go2': 2,
#   'notxt.co.uk': 2,
#   '0808': 3,
#   '145': 3,
#   '4742': 3,
#   '9am-11pm': 3,
#   'important': 6,
#   'announcement.': 3,
#   '0825': 1,
#   '09061790121': 2,
#   'complementary': 1,
#   'WA14': 1,
#   '2PX': 1,
#   'Sender:': 1,
#   ...},
#  'ham': {'Well,': 1,
#   "i'm": 12,
#   'gonna': 4,
#   'finish': 3,
#   'my': 60,
#   'bath': 2,
#   'now.': 9,
#   'Have': 12,
#   'a': 100,
#   'good...fine': 1,
#   'night.': 2,
#   "I've": 4,
#   'reached': 2,
#   'home': 11,
#   'n': 18,
#   'i': 80,
#   'bathe': 2,
#   'liao...': 1,
#   'U': 25,
#   'can': 24,
#   'call': 24,
#   'me': 62,
#   'now...': 1,
#   'Got': 4,
#   'it!': 2,
#   'It': 7,
#   'looks': 1,
#   'scrumptious...': 1,
#   'daddy': 2,
#   'wants': 6,
#   'to': 166,
#   'eat': 8,
#   'you': 182,
#   'all': 22,
#   'night': 6,
#   'long!': 1,
#   'Ok.': 4,
#   'Watching': 4,
#   'cartoon,': 2,
#   'listening': 2,
#   'music': 2,
#   '&amp;': 16,
#   'at': 31,
#   'eve': 2,
#   'had': 11,
#   'go': 24,
#   'temple': 2,
#   'church..': 2,
#   'What': 13,
#   'about': 18,
#   'u?': 4,
#   'Oh': 5,
#   'k.k..where': 1,
#   'did': 4,
#   'take': 8,
#   'test?': 1,
#   'Also': 3,
#   'hi': 1,
#   'wesley': 1,
#   "how've": 1,
#   'been': 8,
#   'Will': 7,
#   'do,': 1,
#   'be': 38,
#   "blake's": 1,
#   'night?': 1,
#   'I': 163,
#   'might': 2,
#   'able': 2,
#   'get': 26,
#   'out': 17,
#   'of': 59,
#   'here': 4,
#   'little': 3,
#   'early': 3,
#   'WHO': 1,
#   'ARE': 3,
#   'YOU': 2,
#   'SEEING?': 1,
#   "I'm": 29,
#   'job': 6,
#   'profile': 1,
#   'seems': 3,
#   'like': 17,
#   'bpo..': 1,
#   'Were': 1,
#   'somewhere': 2,
#   'on': 36,
#   'Fredericksburg': 1,
#   'Nobody': 1,
#   'decide': 2,
#   'where': 9,
#   'and': 83,
#   'dad': 7,
#   'Chinese': 1,
#   'Mm': 1,
#   'not': 27,
#   'entirely': 1,
#   'sure': 6,
#   'understood': 1,
#   'that': 48,
#   'text': 10,
#   'but': 29,
#   'hey.': 1,
#   'Ho.': 1,
#   'Which': 3,
#   'weekend?': 2,
#   'rip': 1,
#   'uterus.': 1,
#   'Dear': 3,
#   'will': 39,
#   'when': 29,
#   'reach': 2,
#   'there': 7,
#   'The': 12,
#   '&lt;#&gt;': 41,
#   'g': 2,
#   'saw': 4,
#   'few': 5,
#   'days': 1,
#   'ago,': 1,
#   'the': 108,
#   'guy': 3,
#   'sell': 3,
#   'wifi': 1,
#   'only': 13,
#   'for': 40,
#   'with': 27,
#   '3g': 1,
#   '.': 13,
#   "That's": 4,
#   'why': 5,
#   'blanked': 1,
#   'him.': 3,
#   'Reckon': 1,
#   'need': 16,
#   'in': 84,
#   'town': 2,
#   'by': 19,
#   'eightish': 1,
#   'walk': 2,
#   'from': 17,
#   '*': 5,
#   'carpark.': 1,
#   'Hui': 1,
#   'xin': 1,
#   'is': 68,
#   'da': 9,
#   'lib.': 1,
#   'Sorry,': 11,
#   "I'll": 25,
#   'later.': 2,
#   'am': 13,
#   'meeting': 5,
#   'sir.': 2,
#   'Otherwise': 2,
#   'part': 6,
#   'time': 14,
#   'na-tuition..': 2,
#   'New': 4,
#   'Theory:': 1,
#   'Argument': 1,
#   'wins': 1,
#   'd': 6,
#   'SITUATION,': 1,
#   'loses': 1,
#   'PERSON.': 1,
#   'So': 16,
#   'dont': 13,
#   'argue': 1,
#   'ur': 28,
#   'friends': 4,
#   'just..': 1,
#   'kick': 1,
#   'them': 12,
#   'say,': 1,
#   'always': 5,
#   'correct.!': 1,
#   'Huh': 1,
#   'cant': 7,
#   '2': 26,
#   'house': 5,
#   'empty': 5,
#   'handed': 1,
#   'right?': 3,
#   'How': 16,
#   'much': 12,
#   'are': 39,
#   'we': 17,
#   'getting?': 1,
#   'Not': 4,
#   'much,': 1,
#   'just': 17,
#   'some': 10,
#   "textin'.": 1,
#   'bout': 2,
#   'you?': 2,
#   "It's": 4,
#   'make': 9,
#   'cry.': 1,
#   'our': 3,
#   'stuff': 1,
#   'happens': 1,
#   'top': 2,
#   'everything': 1,
#   'else,': 1,
#   'it': 27,
#   'pushes': 1,
#   'over': 6,
#   'edge.': 1,
#   'You': 21,
#   "don't": 20,
#   'underdtand': 1,
#   'how': 18,
#   'often': 2,
#   'cry': 1,
#   'sorry,': 1,
#   'sorry': 4,
#   'life.': 2,
#   'sir,': 2,
#   'sent': 4,
#   'an': 6,
#   'email': 2,
#   'log': 1,
#   'into': 4,
#   'usc': 2,
#   'payment': 1,
#   'portal.': 1,
#   'I.ll': 5,
#   'send': 12,
#   'another': 2,
#   'message': 7,
#   'should': 10,
#   'explain': 1,
#   'things': 2,
#   'back': 9,
#   'home.': 4,
#   'great': 9,
#   'weekend.': 2,
#   'Ah,': 1,
#   'well': 4,
#   'confuses': 1,
#   'things,': 1,
#   'doesnt': 2,
#   'it?': 4,
#   'thought': 4,
#   'was': 20,
#   'Maybe': 1,
#   'wrong': 2,
#   'thing': 6,
#   'already': 6,
#   'sort': 1,
#   'invited': 1,
#   '-tho': 1,
#   'he': 12,
#   'may': 1,
#   'come': 24,
#   'cos': 8,
#   'money.': 1,
#   'Is': 10,
#   'she': 6,
#   'replying.': 1,
#   'Has': 1,
#   'boye': 1,
#   'changed': 1,
#   'his': 6,
#   'phone': 8,
#   'number': 6,
#   'Sorry': 6,
#   'going': 13,
#   'first...': 1,
#   'Daddy': 1,
#   'fetch': 2,
#   'ü': 16,
#   'later...': 1,
#   'leaving': 3,
#   'Great.': 2,
#   'P': 1,
#   'diddy': 1,
#   'neighbor': 1,
#   'comes': 3,
#   'toothpaste': 1,
#   'every': 5,
#   'morning': 5,
#   'you,': 4,
#   'Love': 5,
#   '?': 26,
#   'Are': 13,
#   'your': 41,
#   'brother': 1,
#   'Time': 2,
#   'talk': 3,
#   'english': 1,
#   'him': 7,
#   '*grins*': 1,
#   'Say': 1,
#   ':': 1,
#   'Hey': 11,
#   'Muhommad,': 1,
#   'Penny': 1,
#   'says': 3,
#   'hello': 1,
#   'across': 2,
#   'sea': 2,
#   'Your': 5,
#   'ph?': 1,
#   'Ladies': 1,
#   'first': 5,
#   'genus': 1,
#   'second': 4,
#   'k': 2,
#   'does': 3,
#   'simple': 1,
#   'arithmetic': 1,
#   'percentages.': 1,
#   'got': 18,
#   '$': 1,
#   ',': 10,
#   'more': 7,
#   'later': 14,
#   'though.': 2,
#   'Get': 2,
#   'whatever': 3,
#   'feel': 9,
#   'agree.': 1,
#   'stop': 2,
#   'thinkin': 1,
#   'ipad.': 1,
#   'Can': 8,
#   'please': 4,
#   'ask': 10,
#   'macho': 1,
#   'same': 6,
#   'question.': 1,
#   'doing': 6,
#   'list': 2,
#   'buyers.': 1,
#   'My': 12,
#   'use': 4,
#   'same.': 2,
#   'Hi': 7,
#   'Call': 5,
#   'its': 16,
#   'urgnt.': 1,
#   'know': 24,
#   'whats': 1,
#   'problem.': 1,
#   'want': 21,
#   'work': 6,
#   'or': 30,
#   'if': 19,
#   'have': 32,
#   'any': 12,
#   'other': 4,
#   'problem': 2,
#   'least': 2,
#   'tell': 12,
#   'me.': 8,
#   'Wating': 1,
#   'reply.': 1,
#   'Nvm...': 1,
#   'wear': 2,
#   'sport': 1,
#   'shoes': 1,
#   'anyway...': 1,
#   'late': 4,
#   'leh.': 2,
#   'way': 6,
#   'could': 4,
#   'pick': 10,
#   'up?': 1,
#   'Up': 1,
#   'ü...': 1,
#   'Ü': 8,
#   'wan': 4,
#   'then': 18,
#   'lor...': 10,
#   'But': 13,
#   'din': 2,
#   'c': 4,
#   'stripes': 1,
#   'skirt...': 1,
#   'affidavit': 1,
#   'E': 2,
#   'Twiggs': 1,
#   'St,': 1,
#   'division': 1,
#   'g,': 1,
#   'courtroom': 1,
#   '&lt;TIME&gt;': 2,
#   'AM.': 1,
#   'double': 1,
#   'check': 7,
#   'again': 1,
#   'tomorrow': 4,
#   'im': 3,
#   '..': 2,
#   'On': 1,
#   'snowboarding': 1,
#   'trip.': 1,
#   'wondering': 1,
#   'planning': 1,
#   'everyone': 1,
#   'together': 2,
#   'befor': 3,
#   'go..a': 1,
#   'meet': 3,
#   'greet': 1,
#   'kind': 2,
#   'affair?': 1,
#   'Cheers,': 1,
#   'Nokia': 1,
#   'lovly..': 1,
#   'God': 2,
#   'picked': 1,
#   'up': 19,
#   'flower': 1,
#   'dippeditinaDEW,': 1,
#   'lovingly': 1,
#   'touched': 1,
#   'itwhichturnedinto': 1,
#   'u,': 4,
#   'gifted': 1,
#   'tomeandsaid,THIS': 1,
#   'FRIEND': 1,
#   'IS': 2,
#   '4U': 1,
#   'this': 25,
#   'buzy': 2,
#   'think': 11,
#   'mentor': 1,
#   '100': 1,
#   'percent': 1,
#   'sure.': 2,
#   'Sent': 1,
#   'id': 3,
#   'soon': 5,
#   'Haha,': 2,
#   'friend': 6,
#   'tyler': 2,
#   'literally': 1,
#   'asked': 1,
#   'dubsack': 1,
#   'wanted': 4,
#   'wait': 5,
#   '4': 11,
#   'lect.': 1,
#   'Cos': 2,
#   'lect': 1,
#   'finishes': 1,
#   'hour': 4,
#   'anyway.': 2,
#   'Mathews': 1,
#   'tait': 1,
#   'edwards': 1,
#   'anderson': 1,
#   'though': 2,
#   'shd': 3,
#   'fun': 3,
#   'so': 31,
#   'bar': 1,
#   'something': 3,
#   '–': 1,
#   'sound': 1,
#   'ok?': 2,
#   'Yup': 3,
#   'thk': 6,
#   'they': 11,
#   'r': 13,
#   'e': 9,
#   'teacher': 1,
#   'said': 6,
#   'face': 1,
#   'look': 3,
#   'longer.': 1,
#   'Darren': 1,
#   'cut': 3,
#   'too': 8,
#   'short.': 1,
#   'R': 3,
#   'comin': 1,
#   'dinner?': 1,
#   'remember': 5,
#   "dobby's": 1,
#   'bowl': 1,
#   'car': 3,
#   "He's": 1,
#   'lag.': 1,
#   'sad': 2,
#   'keep': 7,
#   'touch': 2,
#   'thanks': 3,
#   'skype': 1,
#   'Lol': 7,
#   'real.': 1,
#   'She': 5,
#   'told': 3,
#   'cancer': 1,
#   'Nothing': 2,
#   'spl..wat': 1,
#   'abt': 2,
#   'u': 61,
#   'whr': 1,
#   'ru?': 1,
#   'Wot': 1,
#   'bitch?': 1,
#   'Congratulations': 1,
#   'ore': 1,
#   'mo': 1,
#   'owo': 1,
#   're': 1,
#   'wa.': 1,
#   'Enjoy': 2,
#   'wish': 8,
#   'many': 3,
#   'happy': 3,
#   'moments': 1,
#   'fro': 1,
#   'wherever': 1,
#   'down': 4,
#   'gandhipuram': 1,
#   'cross': 1,
#   'road.': 1,
#   'Right': 2,
#   'side': 2,
#   'street': 2,
#   'road': 1,
#   'turn': 1,
#   'right.': 1,
#   'Ok..': 1,
#   'finishing': 1,
#   'soon?': 2,
#   'Yar': 1,
#   'Keep': 1,
#   'raining': 1,
#   'non': 1,
#   'stop...': 1,
#   'Or': 3,
#   'elsewhere?': 1,
#   'Where': 7,
#   'abj': 1,
#   'serving.': 1,
#   'staying': 3,
#   'alone.': 1,
#   'Yup,': 1,
#   'right': 4,
#   'now,': 3,
#   'Yeah': 3,
#   'lol': 1,
#   'No': 10,
#   'dude,': 1,
#   'fake..my': 1,
#   'frnds': 1,
#   'money,': 1,
#   'thts': 1,
#   'y': 2,
#   'reffering': 1,
#   'u..if': 1,
#   'member': 1,
#   'wit': 4,
#   'mail': 2,
#   'link,': 1,
#   'vl': 1,
#   'credited': 1,
#   'rs': 1,
#   'il': 1,
#   'getiing': 1,
#   'rs..i': 1,
#   'draw': 1,
#   'acc': 1,
#   'wen': 2,
#   'rs..': 1,
#   'Den': 2,
#   'wat': 3,
#   'schedule': 1,
#   'b': 5,
#   'lk': 1,
#   'sun?': 1,
#   'LMAO': 1,
#   "where's": 1,
#   'fish': 1,
#   'memory': 1,
#   'Shuhui': 1,
#   'has': 12,
#   'bought': 1,
#   "ron's": 1,
#   'present': 2,
#   "it's": 7,
#   'swatch': 1,
#   'watch...': 1,
#   "What's": 2,
#   'up.': 2,
#   'Do': 18,
#   'online?': 1,
#   'lt': 1,
#   '25': 1,
#   'pass': 1,
#   'lar': 1,
#   '1.20': 1,
#   'cost.': 1,
#   'guess': 6,
#   'isnt': 1,
#   'bad.': 1,
#   'Miss': 2,
#   'ya,': 3,
#   'love': 14,
#   'ya': 2,
#   'cool,': 2,
#   'let': 11,
#   'before': 1,
#   'kicks': 1,
#   'off': 5,
#   'around': 7,
#   'day': 14,
#   '....My': 1,
#   'engagement': 1,
#   'fixd': 1,
#   'th': 3,
#   'next': 4,
#   'month.': 4,
#   'really': 8,
#   'shocking': 1,
#   'bt....hmm': 1,
#   'njan': 1,
#   'vilikkam....t': 1,
#   'ws': 1,
#   'al': 2,
#   'sudn;-(.': 1,
#   'Except': 1,
#   'theres': 1,
#   'chick': 1,
#   'huge': 1,
#   'boobs.': 1,
#   'sign': 2,
#   'maturity': 1,
#   'start': 4,
#   'saying': 1,
#   'big': 4,
#   'things..': 1,
#   'actually': 2,
#   'is,': 1,
#   'understanding': 1,
#   'small': 2,
#   'things...': 1,
#   '*HAVE': 1,
#   'A': 11,
#   'NICE': 2,
#   'EVENING*': 1,
#   'BSLVYL': 1,
#   'Aight,': 3,
#   "you're": 5,
#   'usf': 1,
#   'Happy': 6,
#   'new': 10,
#   'years': 1,
#   'melody!': 1,
#   'No.': 3,
#   'Yes': 5,
#   'please.': 2,
#   'Been': 1,
#   'swimming?': 1,
#   'Hello,': 2,
#   'love!': 1,
#   'goes': 3,
#   'fine': 2,
#   'babe': 2,
#   'hope': 7,
#   'find': 8,
#   'prospects.': 1,
#   'miss': 8,
#   'boytoy': 1,
#   '...': 10,
#   '*a': 1,
#   'teasing': 1,
#   'kiss*': 2,
#   'uncles': 1,
#   'Atlanta.': 1,
#   'Wish': 1,
#   'guys': 1,
#   'semester.': 2,
#   'tv': 2,
#   'Dude': 1,
#   'knw': 1,
#   'also': 4,
#   'telugu..thts': 1,
#   'gud..k,': 1,
#   'gud': 3,
#   'nyt..': 1,
#   'haf': 1,
#   'busy...': 1,
#   'Ok': 8,
#   'no': 13,
#   'prob': 2,
#   'see,': 1,
#   'prolly': 1,
#   'yeah': 2,
#   'Derp.': 1,
#   'worse,': 1,
#   'dude': 3,
#   'who': 10,
#   'party': 1,
#   'files': 1,
#   'complaint': 1,
#   'three': 2,
#   'drug': 3,
#   'abusers': 1,
#   'lives': 1,
#   'Send': 2,
#   'birthdate': 1,
#   'month': 3,
#   'year,': 1,
#   'tel': 1,
#   'LIFE': 1,
#   "PARTNER'S": 1,
#   'name.': 1,
#   'method': 1,
#   'calculation.': 1,
#   'Reply': 2,
#   'must.': 1,
#   'Am': 3,
#   'train': 3,
#   'northampton': 1,
#   'afraid': 1,
#   'not!': 1,
#   'skyving': 1,
#   'today': 6,
#   'ho': 1,
#   'ho!': 1,
#   'wednesday': 1,
#   'fancy': 1,
#   'comedy': 1,
#   'club': 1,
#   'week': 2,
#   'way?': 1,
#   'Er': 1,
#   'yep': 1,
#   'Props?': 1,
#   'Thanx': 1,
#   'birthday': 3,
#   'already.': 2,
#   'Hi.': 3,
#   'Hope': 4,
#   'good': 13,
#   'day.': 6,
#   'better': 3,
#   'gotta': 1,
#   'urself.': 1,
#   "i'll": 2,
#   'shopping': 1,
#   'frens': 1,
#   'present.': 1,
#   'Babe': 1,
#   '!': 9,
#   'sip': 1,
#   'cappuccino': 1,
#   'kiss': 1,
#   'Anyway': 1,
#   'secure': 1,
#   'anything': 6,
#   'here,': 2,
#   'lemme': 2,
#   'drive': 2,
#   'south': 1,
#   'chill': 1,
#   'wahala.': 1,
#   'Just': 8,
#   'Awesome,': 2,
#   'plan': 2,
#   'after': 6,
#   'details': 2,
#   'wee': 1,
#   'bit': 3,
#   'If': 8,
#   'sending': 1,
#   'blackberry': 1,
#   'torch': 1,
#   'nigeria': 1,
#   'buyer': 1,
#   'me?like': 1,
#   '4a': 1,
#   'And': 7,
#   'buy': 5,
#   'bb': 3,
#   'anyone': 2,
#   'oh.': 3,
#   'wud': 2,
#   'never': 3,
#   'mind': 4,
#   'me..': 1,
#   'wil': 5,
#   'hurt': 4,
#   'me.........': 1,
#   'Take': 2,
#   'care:-)': 1,
#   'Good': 7,
#   'good,': 1,
#   'billy': 1,
#   'mates': 2,
#   'gone.': 1,
#   'jogging,': 1,
#   'again!': 2,
#   'Did': 7,
#   'enjoy': 1,
#   'concert?': 1,
#   'confirmed': 1,
#   'weekend': 1,
#   'Ok...': 3,
#   'catch': 1,
#   'bus': 1,
#   'frying': 1,
#   'egg': 1,
#   'tea?': 1,
#   'eating': 1,
#   "mom's": 1,
#   'left': 3,
#   'dinner': 1,
#   'Feel': 1,
#   'Yourself': 1,
#   'That': 2,
#   'Always': 1,
#   'Happy..': 1,
#   'Slowly': 1,
#   'Becomes': 2,
#   'Habit': 1,
#   'Finally': 1,
#   'Part': 2,
#   'Of': 1,
#   'Life..': 1,
#   'Follow': 1,
#   'It..': 1,
#   'Morning': 2,
#   'Day:)': 1,
#   'cme': 1,
#   'hos': 1,
#   '2morow.': 1,
#   'After': 2,
#   'cme.': 1,
#   'This': 4,
#   'what': 13,
#   'her': 10,
#   'dear': 3,
#   'do.': 5,
#   'didnt': 2,
#   'say': 5,
#   'file': 1,
#   'bag..i': 1,
#   'called': 4,
#   'me.i': 1,
#   "'ll": 1,
#   'room.': 1,
#   'Probably': 1,
#   'money': 4,
#   'worries.': 1,
#   'Things': 1,
#   'coming': 4,
#   'due': 1,
#   'several': 1,
#   'outstanding': 1,
#   'invoices': 1,
#   'two': 4,
#   'months': 1,
#   'ago.': 1,
#   'opinion': 1,
#   'me?': 1,
#   '1.': 2,
#   'Over': 1,
#   '2.': 2,
#   'Jada': 1,
#   '3.': 2,
#   'Kusruthi': 1,
#   '4.': 2,
#   'Lovable': 1,
#   '5.': 1,
#   'Silent': 1,
#   '6.': 1,
#   'Spl': 1,
#   'character': 1,
#   '7.': 2,
#   'matured': 1,
#   '8.': 1,
#   'Stylish': 1,
#   '9.': 1,
#   'Simple': 1,
#   'Pls': 11,
#   'reply..': 1,
#   'Hopefully': 2,
#   'K': 2,
#   'still': 13,
#   'loving': 1,
#   "anybody's": 1,
#   'number,': 1,
#   "haven't": 2,
#   'tactful': 1,
#   'alex': 1,
#   'Wen': 2,
#   'lovable': 2,
#   'bcums': 2,
#   'angry': 4,
#   'wid': 2,
#   'dnt': 3,
#   'seriously..': 2,
#   'Coz': 3,
#   'being': 8,
#   'most': 2,
#   'childish': 2,
#   'true': 3,
#   'showing': 2,
#   'deep': 2,
#   'affection,': 2,
#   'care': 6,
#   'luv!..': 2,
#   'kettoda': 2,
#   'manda...': 2,
#   'nice': 4,
#   'da.': 8,
#   'JADE': 1,
#   'ITS': 3,
#   'PAUL.': 1,
#   'Y': 2,
#   'DIDN\x92T': 1,
#   'TXT': 2,
#   'ME?': 1,
#   'DO': 1,
#   'REMEMBER': 1,
#   'ME': 5,
#   'FROM': 1,
#   'BARMED?': 1,
#   'WANT': 1,
#   'TALK': 1,
#   'U!': 1,
#   'There': 3,
#   'size': 1,
#   'elephant': 1,
#   'tablets': 1,
#   '&': 1,
#   'shove': 1,
#   'um': 1,
#   'ass!!': 1,
#   'okay.': 2,
#   'over.': 1,
#   'All': 7,
#   'best': 6,
#   'know,': 1,
#   "that's": 4,
#   'everyso': 1,
#   'often,': 1,
#   'panicks': 1,
#   'starts': 1,
#   'goin': 2,
#   'bein': 2,
#   'enough': 4,
#   '…': 6,
#   'In': 5,
#   'sch': 2,
#   'neva': 2,
#   '1st': 2,
#   'lor..': 1,
#   'HAVE': 2,
#   'DATE': 1,
#   'ON': 2,
#   'SUNDAY': 1,
#   'WITH': 1,
#   'WILL!!': 1,
#   'Does': 1,
#   'Same': 1,
#   'consider': 1,
#   'walls': 1,
#   'bunkers': 1,
#   'shit': 2,
#   'important': 1,
#   'because': 1,
#   'play': 3,
#   'peaceful': 1,
#   'place': 4,
#   'high': 1,
#   'matter': 1,
#   "God's": 4,
#   'limit.': 1,
#   'grace': 1,
#   'measure.': 1,
#   'power': 1,
#   'boundaries.': 1,
#   'May': 1,
#   'endless': 1,
#   'blessings': 1,
#   'life...!!': 2,
#   'Gud': 6,
#   'ni8': 1,
#   'Cuz': 1,
#   'ibored.': 1,
#   'don': 1,
#   'wanna': 2,
#   'study': 3,
#   'It,,s': 1,
#   'taxt': 1,
#   'massage....tie-pos': 1,
#   'argh': 1,
#   'ok!': 1,
#   'Lool!': 1,
#   'god': 2,
#   ...}}

# %%
y_hat_train = X_train.map(lambda x: classify_doc(x, class_word_freq, p_classes, V))
residuals = y_train == y_hat_train
residuals.value_counts(normalize=True)
# Out:
# False    0.733036
# True     0.266964
# dtype: float64

# %%
y_hat_test= X_test.map(lambda x: classify_doc(x, class_word_freq, p_classes, V))
residuals = y_test== y_hat_test
residuals.value_counts(normalize=True)
# Out:
# False    0.708556
# True     0.291444
# dtype: float64

# %% [markdown]
# # with `sklearn`

# %%
# from nltk.corpus import stopwords
# from string import punctuation
# stopwords_list = stopwords.words('english')
# stopwords_list += punctuation


# from nltk.tokenize import word_tokenize
# def clean_text(txt):
#     txt = word_tokenize(txt)
#     txt = [w.lower() for w in txt if w not in stopwords_list]
#     return ' '.join(txt)

# %%
 df2['label'].value_counts()

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = df2['text']
y = df2['label'].copy()

X_train, X_test, y_train,y_test =train_test_split(X, y,random_state=17)

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# My way
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train_vec,y_train)

y_hat_test = model.predict(X_test_vec)

print(metrics.classification_report(y_test,y_hat_test))
metrics.plot_confusion_matrix(model,X_test_vec,y_test,cmap='Blues', normalize='true')
y_test.value_counts(normalize=True)

# %%
model.class_count_

# %%
model.classes_

# %%
vocab = vectorizer.vocabulary_
len(vocab)

# %%
model.n_features_

# %%
model.coef_.flatten()

# %%
len(model.coef_.flatten())

# %%
model.feature_count_

# %%
X_test_vec[1]

# %%
vectorizer.inverse_transform(X_test_vec[1])

# %% [markdown]
# ## Level up (Optional)
#
# Rework your code into an appropriate class structure so that you could easily implement the algorithm on any given dataset.

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you practiced implementing Naive Bayes for document classification!
