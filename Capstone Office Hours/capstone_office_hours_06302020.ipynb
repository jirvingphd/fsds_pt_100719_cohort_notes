# %% [markdown]
# # Capstone Office Hours

# %% [markdown]
# ## Announcements

# %%
import requests, bs4

# %%
url = "https://baltimore.craigslist.org/d/apts-housing-for-rent/search/apa"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = bs4.BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js"><head>
# <title>baltimore apts/housing for rent  - craigslist</title>
# <meta content="baltimore apts/housing for rent  - craigslist" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <link href="https://baltimore.craigslist.org/search/apa" rel="canonical"/>
# <link href="https://baltimore.craigslist.org/search/apa?format=rss" rel="alternate" title="RSS feed for craigslist | baltimore apts/housing for rent  - craigslist" type="application/rss+xml"/>
# <link href="https://baltimore.craigslist.org/search/apa?s=120" rel="next"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
result_infos = soup.find_all('p',class_="result-info")
result_infos
# Out:
# [<p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-06-30 19:49" title="Tue 30 Jun 07:49:21 PM">Jun 30</time>
#  <a class="result-title hdrlnk" data-id="7151398136" href="https://baltimore.craigslist.org/apa/d/baltimore-huge-home-in-harbor-east/7151398136.html">Huge home in Harbor East Little Italy</a>
#  <span class="result-meta">
#  <span class="result-price">$1750</span>
#  <span class="housing">
#                      4br -
#                      1608ft<sup>2</sup> -
#                  </span>
#  <span class="result-hood"> (Little Italy, Fells Point, Harbor East Baltimore Maryland)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
# ...

# %%
result_infos[0].find_all('img')
# Out:
# []

# %%
soup = bs4.BeautifulSoup(response.content)
# soup.find_all('img')
# Out:
# [<img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>,
#  <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>]

# %%
url ="https://baltimore.craigslist.org/apa/d/baltimore-tennis-courts-dog-park/7144210743.html"
response= requests.get(url)
soup2= bs4.BeautifulSoup(response.content)
soup.find_all('img')
# Out:
# [<img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>,
#  <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>]

# %%
img="https://res.cloudinary.com/practicaldev/image/fetch/s--KLJcR1tz--/c_imagga_scale,f_auto,fl_progressive,h_900,q_auto,w_1600/https://thepracticaldev.s3.amazonaws.com/i/mplqezmxfupbu7x7d90k.jpg"
response = requests.get(img)

# %%
with open('example_img.jpg','wb') as file:
    file.write(response.content)

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
plt.imshow(plt.imread('example_img.jpg',))

# %%
with open('example_img.png','r') as file:
    Image.open(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-8823e7f2b471> in <module>
#       1 with open('example_img.png','r') as file:
# ----> 2     Image.open(file)
#       3
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2777         exclusive_fp = True
#    2778
# -> 2779     prefix = fp.read(16)
#    2780
#    2781     preinit()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
