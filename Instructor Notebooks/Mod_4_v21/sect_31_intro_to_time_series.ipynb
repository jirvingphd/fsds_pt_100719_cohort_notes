# %% [markdown]
# # Sect 31-Pt1: Intro to Time Series

# %% [markdown]
# - From 12/18/19 study group

# %% [markdown]
# ## Learning Objectives:
# - Learn how to load in timeseries data into pandas
# - Learn how to plot timeseries in pandas
# - Learn how to resample at different time frequencies
# - Learn about types of time series trends and how to remove them.
# - Learn about seasonal decomposition

# %% [markdown]
#  ## Questions to Revisit
#  - Can you interpolate between missing datapoints?

# %% [markdown]
# ## References

# %% [markdown]
# - [Pandas Timeseries Documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html)
# - ['Timeseries Offset Aliases'](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases)
# - [Anchored Offsets](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#anchored-offsets)
#
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %% [markdown]
# **REFERENCE CONTENTS:**
# - Date StrFormatting
#     - Used for:
#         - Recognizing Date Formats (`pd.to_datetime`)
#         - `dt_obj.strftime()`
#
# - Pandas Frequency Aliases
#     - Used for:
#         - `df.resample()`
#         - `df.asfreq()`
#         - ...

# %% [markdown]
# ### Date Str Formatting

# %% [markdown]
# Formatting follows the Python datetime <strong><a href='http://strftime.org/'>strftime</a></strong> codes.<br>
# The following examples are based on <tt>datetime.datetime(2001, 2, 3, 16, 5, 6)</tt>:
# <br><br>
#
# <table style="display: inline-block">
# <tr><th>CODE</th><th>MEANING</th><th>EXAMPLE</th><tr>
# <tr><td>%Y</td><td>Year with century as a decimal number.</td><td>2001</td></tr>
# <tr><td>%y</td><td>Year without century as a zero-padded decimal number.</td><td>01</td></tr>
# <tr><td>%m</td><td>Month as a zero-padded decimal number.</td><td>02</td></tr>
# <tr><td>%B</td><td>Month as locale’s full name.</td><td>February</td></tr>
# <tr><td>%b</td><td>Month as locale’s abbreviated name.</td><td>Feb</td></tr>
# <tr><td>%d</td><td>Day of the month as a zero-padded decimal number.</td><td>03</td></tr>
# <tr><td>%A</td><td>Weekday as locale’s full name.</td><td>Saturday</td></tr>
# <tr><td>%a</td><td>Weekday as locale’s abbreviated name.</td><td>Sat</td></tr>
# <tr><td>%H</td><td>Hour (24-hour clock) as a zero-padded decimal number.</td><td>16</td></tr>
# <tr><td>%I</td><td>Hour (12-hour clock) as a zero-padded decimal number.</td><td>04</td></tr>
# <tr><td>%p</td><td>Locale’s equivalent of either AM or PM.</td><td>PM</td></tr>
# <tr><td>%M</td><td>Minute as a zero-padded decimal number.</td><td>05</td></tr>
# <tr><td>%S</td><td>Second as a zero-padded decimal number.</td><td>06</td></tr>
# </table>
# <table style="display: inline-block">
# <tr><th>CODE</th><th>MEANING</th><th>EXAMPLE</th><tr>
# <tr><td>%#m</td><td>Month as a decimal number. (Windows)</td><td>2</td></tr>
# <tr><td>%-m</td><td>Month as a decimal number. (Mac/Linux)</td><td>2</td></tr>
# <tr><td>%#x</td><td>Long date</td><td>Saturday, February 03, 2001</td></tr>
# <tr><td>%#c</td><td>Long date and time</td><td>Saturday, February 03, 2001 16:05:06</td></tr>
# </table>

# %% [markdown]
# ### Pandas Frequency Aliases

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases
#
#
# |Alias	| Description|
# | --- | --- |
# |B |	business day frequency|
# |C |	custom business day frequency|
# |D |	calendar day frequency|
# |W |	weekly frequency|
# |M |	month end frequency|
# |SM |	semi-month end frequency (15th and end of month)|
# |BM |	business month end frequency|
# |CBM |	custom business month end frequency|
# |MS |	month start frequency|
# |SMS |	semi-month start frequency (1st and 15th)|
# |BMS |	business month start frequency|
# |CBMS |	custom business month start frequency|
# |Q |	quarter end frequency|
# |BQ |	business quarter end frequency|
# |QS |	quarter start frequency|
# |BQS |	business quarter start frequency|
# |A, Y |	year end frequency|
# |BA, BY |	business year end frequency|
# |AS, YS |	year start frequency|
# |BAS, BYS |	business year start frequency|
# |BH | business hour frequency|
# |H | hourly frequency|
# |T |  min	minutely frequency|
# |S | secondly frequency|
# |L |  ms	milliseconds|
# |U |  us	microseconds|
# |N | nanoseconds|

# %% [markdown]
# # Intro to Time Series

# %%
# !pip install -U fsds_100719
from fsds_100719.imports import *
# Out:
# fsds_1007219  v0.7.21 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row1_col1" class="data row1 col1" >fsds_100719</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_5aa47500_8cd1_11ea_bc7d_4865ee12e626row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %%
df = fs.datasets.load_mod1_proj()
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
date = pd.to_datetime(df['date'])
date
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['d_date'] = pd.to_datetime(df['date'])
display(df.head())
df.dtypes
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...        1180            0.0
# 1      7242     2.0         0.0   0.0  ...        2170          400.0
# 2     10000     1.0         0.0   0.0  ...         770            0.0
# 3      5000     1.0         0.0   0.0  ...        1050          910.0
# 4      8080     1.0         0.0   0.0  ...        1680            0.0
#
#    yr_built yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955          0.0    98178  47.5112 -122.257           1340
# 1      1951       1991.0    98125  47.7210 -122.319           1690
# 2      1933          NaN    98028  47.7379 -122.233           2720
# 3      1965          0.0    98136  47.5208 -122.393           1360
# 4      1987          0.0    98074  47.6168 -122.045           1800
#
#    sqft_lot15     d_date
# 0        5650 2014-10-13
# 1        7639 2014-12-09
# 2        8062 2015-02-25
# 3        5000 2014-12-09
# 4        7503 2015-02-18
#
# [5 rows x 22 columns]
# id                        int64
# date                     object
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront              float64
# view                    float64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement            object
# yr_built                  int64
# yr_renovated            float64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# d_date           datetime64[ns]
# dtype: object

# %%
df.set_index('d_date',inplace=True)
df.index
# Out:
# DatetimeIndex(['2014-10-13', '2014-12-09', '2015-02-25', '2014-12-09',
#                '2015-02-18', '2014-05-12', '2014-06-27', '2015-01-15',
#                '2015-04-15', '2015-03-12',
#                ...
#                '2014-08-25', '2015-01-26', '2014-10-14', '2015-03-26',
#                '2015-02-19', '2014-05-21', '2015-02-23', '2014-06-23',
#                '2015-01-16', '2014-10-15'],
#               dtype='datetime64[ns]', name='d_date', length=21597, freq=None)

# %%
mpl.rcParams['figure.figsize'] = (12,6)

# %%
df['price'].plot()

# %% [markdown]
# ### Slicing With Time Series

# %% [markdown]
# - Make sure you're index is sorted first'
# - Feed in 2 dates as strings for slicing.
# - Always use .loc when slicing dates

# %%
df.sort_index(inplace=True)

# %%
df.loc['2014-05-01':'2015-05-01','price'].plot().autoscale(axis='x',tight=True)

# %% [markdown]
# ## Time series Frequencies

# %%
df.index
# Out:
# DatetimeIndex(['2014-05-02', '2014-05-02', '2014-05-02', '2014-05-02',
#                '2014-05-02', '2014-05-02', '2014-05-02', '2014-05-02',
#                '2014-05-02', '2014-05-02',
#                ...
#                '2015-05-14', '2015-05-14', '2015-05-14', '2015-05-14',
#                '2015-05-14', '2015-05-14', '2015-05-14', '2015-05-15',
#                '2015-05-24', '2015-05-27'],
#               dtype='datetime64[ns]', name='d_date', length=21597, freq=None)

# %%
df.index
# Out:
# DatetimeIndex(['2014-05-02', '2014-05-02', '2014-05-02', '2014-05-02',
#                '2014-05-02', '2014-05-02', '2014-05-02', '2014-05-02',
#                '2014-05-02', '2014-05-02',
#                ...
#                '2015-05-14', '2015-05-14', '2015-05-14', '2015-05-14',
#                '2015-05-14', '2015-05-14', '2015-05-14', '2015-05-15',
#                '2015-05-24', '2015-05-27'],
#               dtype='datetime64[ns]', name='d_date', length=21597, freq=None)

# %%
ts = df['price']

# %%
freq_codes = ['D','3D','W','M', 'Q']
for freq in freq_codes:
    plt.figure()
    title=f"Freq Code: {freq}"
    plt.legend()
    ts.resample(freq).mean().plot(title=title)
    
ax = ts.resample('M').mean().plot(kind='bar')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
ts.resample('D').mean().plot()

# %% [markdown]
# ## Using Datetime objects and apply statemements

# %%
display(df.head())
df.dtypes
# Out:
#                     id      date     price  bedrooms  bathrooms  sqft_living  \
# d_date
# 2014-05-02  2202500290  5/2/2014  435000.0         4        1.0         1450
# 2014-05-02  7853361370  5/2/2014  555000.0         4        2.5         3310
# 2014-05-02  7197300105  5/2/2014  550000.0         4        2.5         1940
# 2014-05-02  3438501320  5/2/2014  295000.0         2        2.5         1630
# 2014-05-02   472000620  5/2/2014  790000.0         3        2.5         2600
#
#             sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# d_date                                          ...
# 2014-05-02      8800     1.0         0.0   0.0  ...      7        1450
# 2014-05-02      6500     2.0         0.0   0.0  ...      8        3310
# 2014-05-02     10500     1.0         NaN   0.0  ...      7        1140
# 2014-05-02      1368     2.0         0.0   0.0  ...      7        1280
# 2014-05-02      4750     1.0         0.0   0.0  ...      9        1700
#
#             sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# d_date
# 2014-05-02            0.0     1954           0.0    98006  47.5746 -122.135
# 2014-05-02            0.0     2012           0.0    98065  47.5150 -121.870
# 2014-05-02          800.0     1976           0.0    98052  47.6830 -122.114
# 2014-05-02          350.0     2009           0.0    98106  47.5489 -122.363
# 2014-05-02          900.0     1951           0.0    98117  47.6833 -122.400
#
#             sqft_living15  sqft_lot15
# d_date
# 2014-05-02           1260        8942
# 2014-05-02           2380        5000
# 2014-05-02           2200       10500
# 2014-05-02           1590        2306
# 2014-05-02           2380        4750
#
# [5 rows x 21 columns]
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement     object
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
t = df.index.to_series()[0]
display(t)
print(t)
# Out:
# Timestamp('2014-05-02 00:00:00')
# 2014-05-02 00:00:00

# %%
# help(t.strptime)

# %%
print(t.strftime("%m-%d-%Y"))
print(t.strftime("%T"))
# Out:
# 05-02-2014
# 00:00:00

# %%
df.index
# Out:
# DatetimeIndex(['2014-05-02', '2014-05-02', '2014-05-02', '2014-05-02',
#                '2014-05-02', '2014-05-02', '2014-05-02', '2014-05-02',
#                '2014-05-02', '2014-05-02',
#                ...
#                '2015-05-14', '2015-05-14', '2015-05-14', '2015-05-14',
#                '2015-05-14', '2015-05-14', '2015-05-14', '2015-05-15',
#                '2015-05-24', '2015-05-27'],
#               dtype='datetime64[ns]', name='d_date', length=21597, freq=None)

# %%
df['month'] = df.index.to_series().apply(lambda x: x.month)
df.head()
# Out:
#                     id      date     price  bedrooms  bathrooms  sqft_living  \
# d_date
# 2014-05-02  2202500290  5/2/2014  435000.0         4        1.0         1450
# 2014-05-02  7853361370  5/2/2014  555000.0         4        2.5         3310
# 2014-05-02  7197300105  5/2/2014  550000.0         4        2.5         1940
# 2014-05-02  3438501320  5/2/2014  295000.0         2        2.5         1630
# 2014-05-02   472000620  5/2/2014  790000.0         3        2.5         2600
#
#             sqft_lot  floors  waterfront  view  ...  sqft_above  \
# d_date                                          ...
# 2014-05-02      8800     1.0         0.0   0.0  ...        1450
# 2014-05-02      6500     2.0         0.0   0.0  ...        3310
# 2014-05-02     10500     1.0         NaN   0.0  ...        1140
# 2014-05-02      1368     2.0         0.0   0.0  ...        1280
# 2014-05-02      4750     1.0         0.0   0.0  ...        1700
#
#             sqft_basement  yr_built yr_renovated  zipcode      lat     long  \
# d_date
# 2014-05-02            0.0      1954          0.0    98006  47.5746 -122.135
# 2014-05-02            0.0      2012          0.0    98065  47.5150 -121.870
# 2014-05-02          800.0      1976          0.0    98052  47.6830 -122.114
# 2014-05-02          350.0      2009          0.0    98106  47.5489 -122.363
# 2014-05-02          900.0      1951          0.0    98117  47.6833 -122.400
#
#             sqft_living15  sqft_lot15  month
# d_date
# 2014-05-02           1260        8942      5
# 2014-05-02           2380        5000      5
# 2014-05-02           2200       10500      5
# 2014-05-02           1590        2306      5
# 2014-05-02           2380        4750      5
#
# [5 rows x 22 columns]

# %%
## Let's make a month column to groupby
df['month_int'] = df.index.to_series().apply(lambda x: x.month) #x
df['month_name'] =df.index.to_series().apply(lambda x:x.strftime("%B"))

for col in ['month_int','month_name']:
    display(df[col].value_counts(normalize=True))
# Out:
# 5     0.111775
# 4     0.103209
# 7     0.102375
# 6     0.100847
# 8     0.089781
# 10    0.086864
# 3     0.086818
# 9     0.082002
# 12    0.068065
# 11    0.065241
# 2     0.057740
# 1     0.045284
# Name: month_int, dtype: float64
# May          0.111775
# April        0.103209
# July         0.102375
# June         0.100847
# August       0.089781
# October      0.086864
# March        0.086818
# September    0.082002
# December     0.068065
# November     0.065241
# February     0.057740
# January      0.045284
# Name: month_name, dtype: float64

# %%
# url = "https://en.wikipedia.org/wiki/2015_Baltimore_protests"
# pre_riot = crime_2014.loc['2015':'2016']
# pre_riot

# %%
df.index.to_series().apply(lambda x: x.month)
# Out:
# d_date
# 2014-05-02    5
# 2014-05-02    5
# 2014-05-02    5
# 2014-05-02    5
# 2014-05-02    5
#              ..
# 2015-05-14    5
# 2015-05-14    5
# 2015-05-15    5
# 2015-05-24    5
# 2015-05-27    5
# Name: d_date, Length: 21597, dtype: int64

# %%
help(ax.xaxis.set_ticklabels)
# Out:
# Help on method set_ticklabels in module matplotlib.axis:
#
# set_ticklabels(ticklabels, *args, minor=False, **kwargs) method of matplotlib.axis.XAxis instance
#     Set the text values of the tick labels.
#
#     Parameters
#     ----------
#     ticklabels : sequence of str or of `Text`\s
#         List of texts for tick labels; must include values for non-visible
#         labels.
#     minor : bool
#         If True, set minor ticks instead of major ticks.
#     **kwargs
#         Text properties.
#
#     Returns
#     -------
#     labels : list of `Text`\s
#         For each tick, includes ``tick.label1`` if it is visible, then
#         ``tick.label2`` if it is visible, in that order.

# %%
fig = ax.get_figure()

ax.xaxis.set_ticklabels(ax.xaxis.get_ticklabels(),**{'rotation':45,
                                                    'ha':'right'}) 
fig

# %%
# df.resample('D').fillna(method='ffill')

# %%
# df.loc['2014-05-01':]['price'].plot()#,'price']

# %%
# df['price'].hist(bins='auto')

# %% [markdown]
# ## Time Series Calculations

# %% [markdown]
# ### Rolling Statistics

# %%
ts_mean = ts.resample('D').mean()
ts_mean.rolling(window=7).mean().head(20)
ts_mean.plot()

# %%
plt.figure(figsize=(12,12))
ts_mean = ts.resample('D').mean()
ts_mean.plot(label='Day')

ts_mean.rolling(window=7).mean().plot(label='Rolling Mean')
ts_mean.rolling(window=7).std().plot(label='Rolling Std')

plt.legend()

# %%
ts_mean.fillna(method='ffill',inplace=True)

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(ts_mean)#.fillna(method='ffill'))
# Out:
# (-18.75304124383,
#  2.0273774397840847e-30,
#  0,
#  390,
#  {'1%': -3.4472291365835566,
#   '5%': -2.8689795375849223,
#   '10%': -2.5707330834976987},
#  9848.746524747772)

# %%
## Lab Function
def stationarity_check(TS,plot=True,col=None):
    """From: https://learn.co/tracks/data-science-career-v2/module-4-a-complete-data-science-project-using-multiple-regression/working-with-time-series-data/time-series-decomposition
    """
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller

    if col is not None:
        # Perform the Dickey Fuller Test
        dftest = adfuller(TS[col]) # change the passengers column as required 
    else:
        dftest=adfuller(TS)
 
    if plot:
        # Calculate rolling statistics
        rolmean = TS.rolling(window = 8, center = False).mean()
        rolstd = TS.rolling(window = 8, center = False).std()

        #Plot rolling statistics:
        fig = plt.figure(figsize=(12,6))
        orig = plt.plot(TS, color='blue',label='Original')
        mean = plt.plot(rolmean, color='red', label='Rolling Mean')
        std = plt.plot(rolstd, color='black', label = 'Rolling Std')
        plt.legend(loc='best')
        plt.title('Rolling Mean & Standard Deviation')
#     plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print ('Results of Dickey-Fuller Test:')

    dfoutput = pd.Series(dftest[0:4],
                         index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
        
    dfoutput['sig'] = dfoutput['p-value']<.05
    print (dfoutput)
    
    return dfoutput

# %%
stationarity_check(ts_mean);
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.875304e+01
# p-value                        2.027377e-30
# #Lags Used                     0.000000e+00
# Number of Observations Used    3.900000e+02
# Critical Value (1%)           -3.447229e+00
# Critical Value (5%)           -2.868980e+00
# Critical Value (10%)          -2.570733e+00
# sig                            1.000000e+00
# dtype: float64

# %%
ts_cleaned = ts_mean-ts_mean.rolling(7).mean()
ts_mean.plot()
ts_cleaned.plot()

# %% [markdown]
# ## Time Series Trends

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-removing-trends-online-ds-ft-100719/master/images/new_trendseasonal.png" width=50%>

# %% [markdown]
# ### Stationarity

# %% [markdown]
# <div style="text-align:center;font-size:2em">Mean</div>
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-types-of-trends-online-ds-ft-100719/master/images/new_mean_nonstationary.png" width=70%>
# <br><br>
# <div style="text-align:center;font-size:3em">Variance</div>
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-types-of-trends-online-ds-ft-100719/master/images/new_cov_nonstationary.png" width=70%>
# </div>

# %% [markdown]
# ### Types of Trends

# %% [markdown]
# - https://learn.co/tracks/data-science-career-v2/module-4-a-complete-data-science-project-using-multiple-regression/working-with-time-series-data/types-of-trends

# %% [markdown]
# ### Removing Trends
# - .diff()
# - subtract rolling mean
# - seasonal decomposition

# %% [markdown]
# ## New ts datasets to test

# %%
# baltimore_crime ="https://raw.githubusercontent.com/jirvingphd/fsds_100719/master/fsds_100719/data/BPD_Part_1_Victim_Based_Crime_Data.csv"
# std_rates = "https://raw.githubusercontent.com/jirvingphd/fsds_100719/master/fsds_100719/data/STD%20Cases.csv"
# no_sex_xlsx = "https://raw.githubusercontent.com/jirvingphd/fsds_100719/master/fsds_100719/data/Americans%20Sex%20Frequency.xlsx"

learn_passengers="https://raw.githubusercontent.com/learn-co-students/dsc-removing-trends-lab-online-ds-ft-100719/master/passengers.csv"

# %% [markdown]
# ## Baltimore Crime

# %%
baltimore_crime ="https://raw.githubusercontent.com/jirvingphd/fsds_100719/master/fsds_100719/data/BPD_Part_1_Victim_Based_Crime_Data.csv"
df = pd.read_csv(baltimore_crime,low_memory=False,parse_dates=True)
df.sort_index(inplace=True)
df.head()
# Out:
#     CrimeDate CrimeTime CrimeCode             Location          Description  \
# 0  12/14/2019  00:26:00        1A  2400 W BELVEDERE AV             HOMICIDE
# 1  12/14/2019  07:30:00        3B      600 S MONROE ST     ROBBERY - STREET
# 2  12/14/2019  14:30:00       3JK   3000 E MONUMENT ST  ROBBERY - RESIDENCE
# 3  12/14/2019  14:15:00        4A     1100 MCCULLOH ST         AGG. ASSAULT
# 4  12/14/2019  04:03:00        5E  400 E BELVEDERE AVE             BURGLARY
#
#   Inside/Outside   Weapon Post  District            Neighborhood  Longitude  \
# 0        Outside  FIREARM  532  NORTHERN               LEVINDALE      -77.0
# 1              O      NaN  934  SOUTHERN        CARROLLTON RIDGE      -77.0
# 2              I    KNIFE  333   EASTERN    ELLWOOD PARK/MONUMEN      -77.0
# 3              O  FIREARM  123   CENTRAL  LOWER HERRING RUN PARK      -77.0
# 4              O      NaN  523  NORTHERN                ROSEBANK      -77.0
#
#    Latitude  Location 1            Premise vri_name1  Total Incidents
# 0      39.0         NaN           HOSPITAL       NaN                1
# 1      39.0         NaN             STREET       NaN                1
# 2      39.0         NaN  ROW/TOWNHOUSE-OCC       NaN                1
# 3      39.0         NaN             STREET       NaN                1
# 4      39.0         NaN    OTHER - OUTSIDE       NaN                1

# %%
plot_kws= {'title':'Most Prevalent Crime Types','figsize':(12,7)}#,
df["Description"].value_counts(ascending=True,
                              normalize=True).plot(kind='barh',**plot_kws)

# %%
df['date'] = pd.to_datetime(df['CrimeDate'])
df.set_index('date',inplace=True)
df.sort_index(inplace=True)

# %%
df
# Out:
#              CrimeDate CrimeTime CrimeCode               Location  \
# date
# 1963-10-30  10/30/1963  00:00:00        2A      3100 FERNDALE AVE
# 1969-07-20  07/20/1969  21:00:00        2A        5400 ROLAND AVE
# 1975-06-01  06/01/1975  00:00:00        2A  4400 OLD FREDERICK RD
# 1977-05-01  05/01/1977  00:01:00        2A          600 W 34TH ST
# 1978-01-01  01/01/1978  10:30:00        2A        1900 ARGONNE DR
# ...                ...       ...       ...                    ...
# 2019-12-14  12/14/2019  01:05:00        4E       300 S CHARLES ST
# 2019-12-14  12/14/2019  10:30:00        4D       3200 N HILTON ST
# 2019-12-14  12/14/2019  00:52:00        6E      1700 N CALHOUN ST
# 2019-12-14  12/14/2019  10:00:00        6D      500 SAINT PAUL ST
# 2019-12-14  12/14/2019  00:26:00        1A    2400 W BELVEDERE AV
#
#                   Description Inside/Outside   Weapon Post   District  \
# date
# 1963-10-30               RAPE              I    OTHER  622  NORTHWEST
# 1969-07-20               RAPE            NaN    OTHER  534   NORTHERN
# 1975-06-01               RAPE              I    OTHER  822  SOUTHWEST
# 1977-05-01               RAPE              I    OTHER  531   NORTHERN
# 1978-01-01               RAPE              I    OTHER  421  NORTHEAST
# ...                       ...            ...      ...  ...        ...
# 2019-12-14     COMMON ASSAULT              I      NaN  113    CENTRAL
# 2019-12-14       AGG. ASSAULT              I    HANDS  623  NORTHWEST
# 2019-12-14            LARCENY              O      NaN  734    WESTERN
# 2019-12-14  LARCENY FROM AUTO              O      NaN  124    CENTRAL
# 2019-12-14           HOMICIDE        Outside  FIREARM  532   NORTHERN
#
#                     Neighborhood  Longitude  Latitude  Location 1  \
# date
# 1963-10-30           HOWARD PARK      -77.0      39.0         NaN
# 1969-07-20           ROLAND PARK      -77.0      39.0         NaN
# 1975-06-01               UPLANDS      -77.0      39.0         NaN
# 1977-05-01            WYMAN PARK      -77.0      39.0         NaN
# 1978-01-01  MORGAN STATE UNIVERS      -77.0      39.0         NaN
# ...                          ...        ...       ...         ...
# 2019-12-14          INNER HARBOR      -77.0      39.0         NaN
# 2019-12-14           FOREST PARK      -77.0      39.0         NaN
# 2019-12-14   SANDTOWN-WINCHESTER      -77.0      39.0         NaN
# 2019-12-14          MOUNT VERNON      -77.0      39.0         NaN
# 2019-12-14             LEVINDALE      -77.0      39.0         NaN
#
#                       Premise vri_name1  Total Incidents
# date
# 1963-10-30  ROW/TOWNHOUSE-OCC       NaN                1
# 1969-07-20                NaN       NaN                1
# 1975-06-01     OTHER - INSIDE       NaN                1
# 1977-05-01  ROW/TOWNHOUSE-OCC       NaN                1
# 1978-01-01  ROW/TOWNHOUSE-OCC       NaN                1
# ...                       ...       ...              ...
# 2019-12-14        HOTEL/MOTEL       NaN                1
# 2019-12-14  ROW/TOWNHOUSE-OCC       NaN                1
# 2019-12-14             STREET   Western                1
# 2019-12-14             STREET       NaN                1
# 2019-12-14           HOSPITAL       NaN                1
#
# [286609 rows x 16 columns]

# %% [markdown]
# ## Getting Dummies of Crime Types for Counts

# %%
df_crimes = pd.get_dummies(df,columns=['Description'])

crime_cols = [col for col in df_crimes.columns if 'Description_' in col]
new_names = [x.replace('Description_','') for x in crime_cols]

rename_dict = dict(zip(crime_cols,new_names))
df_crimes.rename(rename_dict,axis=1,inplace=True)

df_crimes
# Out:
#              CrimeDate CrimeTime CrimeCode               Location  \
# date
# 1963-10-30  10/30/1963  00:00:00        2A      3100 FERNDALE AVE
# 1969-07-20  07/20/1969  21:00:00        2A        5400 ROLAND AVE
# 1975-06-01  06/01/1975  00:00:00        2A  4400 OLD FREDERICK RD
# 1977-05-01  05/01/1977  00:01:00        2A          600 W 34TH ST
# 1978-01-01  01/01/1978  10:30:00        2A        1900 ARGONNE DR
# ...                ...       ...       ...                    ...
# 2019-12-14  12/14/2019  01:05:00        4E       300 S CHARLES ST
# 2019-12-14  12/14/2019  10:30:00        4D       3200 N HILTON ST
# 2019-12-14  12/14/2019  00:52:00        6E      1700 N CALHOUN ST
# 2019-12-14  12/14/2019  10:00:00        6D      500 SAINT PAUL ST
# 2019-12-14  12/14/2019  00:26:00        1A    2400 W BELVEDERE AV
#
#            Inside/Outside   Weapon Post   District          Neighborhood  \
# date
# 1963-10-30              I    OTHER  622  NORTHWEST           HOWARD PARK
# 1969-07-20            NaN    OTHER  534   NORTHERN           ROLAND PARK
# 1975-06-01              I    OTHER  822  SOUTHWEST               UPLANDS
# 1977-05-01              I    OTHER  531   NORTHERN            WYMAN PARK
# 1978-01-01              I    OTHER  421  NORTHEAST  MORGAN STATE UNIVERS
# ...                   ...      ...  ...        ...                   ...
# 2019-12-14              I      NaN  113    CENTRAL          INNER HARBOR
# 2019-12-14              I    HANDS  623  NORTHWEST           FOREST PARK
# 2019-12-14              O      NaN  734    WESTERN   SANDTOWN-WINCHESTER
# 2019-12-14              O      NaN  124    CENTRAL          MOUNT VERNON
# 2019-12-14        Outside  FIREARM  532   NORTHERN             LEVINDALE
#
#             Longitude  ...  COMMON ASSAULT  HOMICIDE LARCENY  \
# date                   ...
# 1963-10-30      -77.0  ...               0         0       0
# 1969-07-20      -77.0  ...               0         0       0
# 1975-06-01      -77.0  ...               0         0       0
# 1977-05-01      -77.0  ...               0         0       0
# 1978-01-01      -77.0  ...               0         0       0
# ...               ...  ...             ...       ...     ...
# 2019-12-14      -77.0  ...               1         0       0
# 2019-12-14      -77.0  ...               0         0       0
# 2019-12-14      -77.0  ...               0         0       1
# 2019-12-14      -77.0  ...               0         0       0
# 2019-12-14      -77.0  ...               0         1       0
#
#            LARCENY FROM AUTO  RAPE  ROBBERY - CARJACKING  \
# date
# 1963-10-30                 0     1                     0
# 1969-07-20                 0     1                     0
# 1975-06-01                 0     1                     0
# 1977-05-01                 0     1                     0
# 1978-01-01                 0     1                     0
# ...                      ...   ...                   ...
# 2019-12-14                 0     0                     0
# 2019-12-14                 0     0                     0
# 2019-12-14                 0     0                     0
# 2019-12-14                 1     0                     0
# 2019-12-14                 0     0                     0
#
#             ROBBERY - COMMERCIAL  ROBBERY - RESIDENCE  ROBBERY - STREET  \
# date
# 1963-10-30                     0                    0                 0
# 1969-07-20                     0                    0                 0
# 1975-06-01                     0                    0                 0
# 1977-05-01                     0                    0                 0
# 1978-01-01                     0                    0                 0
# ...                          ...                  ...               ...
# 2019-12-14                     0                    0                 0
# 2019-12-14                     0                    0                 0
# 2019-12-14                     0                    0                 0
# 2019-12-14                     0                    0                 0
# 2019-12-14                     0                    0                 0
#
#             SHOOTING
# date
# 1963-10-30         0
# 1969-07-20         0
# 1975-06-01         0
# 1977-05-01         0
# 1978-01-01         0
# ...              ...
# 2019-12-14         0
# 2019-12-14         0
# 2019-12-14         0
# 2019-12-14         0
# 2019-12-14         0
#
# [286609 rows x 29 columns]

# %% [markdown]
# ___

# %%
keep_cols = ['CrimeDate','CrimeTime']
keep_cols.extend(new_names)

keep_cols
# Out:
# ['CrimeDate',
#  'CrimeTime',
#  'AGG. ASSAULT',
#  'ARSON',
#  'AUTO THEFT',
#  'BURGLARY',
#  'COMMON ASSAULT',
#  'HOMICIDE',
#  'LARCENY',
#  'LARCENY FROM AUTO',
#  'RAPE',
#  'ROBBERY - CARJACKING',
#  'ROBBERY - COMMERCIAL',
#  'ROBBERY - RESIDENCE',
#  'ROBBERY - STREET',
#  'SHOOTING']

# %%
df_crimes = df_crimes.loc["2014":]
df_crimes.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2014-01-01', '2014-01-01',
#                ...
#                '2019-12-14', '2019-12-14', '2019-12-14', '2019-12-14',
#                '2019-12-14', '2019-12-14', '2019-12-14', '2019-12-14',
#                '2019-12-14', '2019-12-14'],
#               dtype='datetime64[ns]', name='date', length=286528, freq=None)

# %%
df_crimes= df_crimes.loc["2014":][keep_cols]
display(df_crimes.index)
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2014-01-01', '2014-01-01',
#                ...
#                '2019-12-14', '2019-12-14', '2019-12-14', '2019-12-14',
#                '2019-12-14', '2019-12-14', '2019-12-14', '2019-12-14',
#                '2019-12-14', '2019-12-14'],
#               dtype='datetime64[ns]', name='date', length=286528, freq=None)

# %% [markdown]
# ___

# %%
# df_crimes['LARCENY'].plot()

# %% [markdown]
# ## `pd.grouper`

# %%
## Traditional Groupby
df_crimes.groupby(pd.Grouper(freq='D')).sum()[new_names].plot(figsize=(12,6)).autoscale()

# %%
df_crimes.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2014-01-01', '2014-01-01',
#                ...
#                '2019-12-14', '2019-12-14', '2019-12-14', '2019-12-14',
#                '2019-12-14', '2019-12-14', '2019-12-14', '2019-12-14',
#                '2019-12-14', '2019-12-14'],
#               dtype='datetime64[ns]', name='date', length=286528, freq=None)

# %%
df_crimes.groupby(pd.Grouper(freq='D')).sum().plot()

# %%
df_crimes['BURGLARY'].resample('D').sum().plot()
df_crimes['SHOOTING'].resample('D').sum().plot()
df_crimes['HOMICIDE'].resample('D').sum().plot()

# %%
df_counts = df_crimes.groupby('CrimeDate').count()[new_names]
df_counts.index = pd.to_datetime(df_counts.index)
df_counts['BURGLARY'].plot()

# %%
df_counts.sort_index(inplace=True)

# %%
# df_counts.loc['2014':].plot()
# plt.legend(None)
df_2015 = df_counts.loc['2015':'2016']
ax = df_2015.plot()
fig=ax.get_figure()

# %%
riots_start ='2015-04-18' 
ax.axvline(riots_start)

riots_end = '2015-05-03' 
ax.axvline(riots_end)

ax.set_xlim(riots_start,riots_end)
# Out:
# (16543, 16558)

# %%
df_2015.idxmax()
# Out:
# AGG. ASSAULT           2015-04-27
# ARSON                  2015-04-27
# AUTO THEFT             2015-04-27
# BURGLARY               2015-04-27
# COMMON ASSAULT         2015-04-27
# HOMICIDE               2015-04-27
# LARCENY                2015-04-27
# LARCENY FROM AUTO      2015-04-27
# RAPE                   2015-04-27
# ROBBERY - CARJACKING   2015-04-27
# ROBBERY - COMMERCIAL   2015-04-27
# ROBBERY - RESIDENCE    2015-04-27
# ROBBERY - STREET       2015-04-27
# SHOOTING               2015-04-27
# dtype: datetime64[ns]

# %% [markdown]
# # Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
seasonal_decompose(df_2015).plot();

# %%
# url = "https://en.wikipedia.org/wiki/2015_Baltimore_protests"
# pre_riot = crime_2014.loc['2015':'2016']
# pre_riot
